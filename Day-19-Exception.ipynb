# %% [markdown]
# ## Syntax Errors

# %%
if 1==0
print(0)
# Out:
#   Cell In[2], line 1
#     if 1==0
#            ^
# SyntaxError: expected ':'

# %%
print("Hello)
print(1)
# Out:
#   Cell In[3], line 1
#     print("Hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("Hello"
# Out:
#   Cell In[5], line 1
#     print("Hello"
#                  ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# ## Runtime Errors

# %%
a = 10
a.append(20)
print(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 a = 10
# ----> 2 a.append(20)
#       3 print(a)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
a = 10
b = 0
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 a = 10
#       2 b = 0
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
# index error
lst = [10, 20, 30]
print(lst[2])
print(lst[6])
# Out:
# 30
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 lst = [10, 20, 30]
#       3 print(lst[2])
# ----> 4 print(lst[6])
#
# IndexError: list index out of range

# %%
t = (1,2,3,4)
t[0] = 100
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 t = (1,2,3,4)
# ----> 2 t[0] = 100
#       3 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
if 1==1:
print(1)
# Out:
#   Cell In[11], line 2
#     print(1)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
s = "python"
print(s+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 s = "python"
# ----> 2 print(s+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
try:
    a = 10
    b = 2
    c = a / b
    print(c)
except:
    print("something wrong in logic")
# Out:
# 5.0

# %%
try:
    a = 10
    b = 0
    c = a / b
    print(c)
except:
    print("something wrong in logic")
# Out:
# something wrong in logic

# %%
# execute the coresponding except block error
try:
    a = 10
    c = a + "Hi"
    print(c)
except ZeroDivisionError:
    print('Zero Division not possible')
except:
    print("something wrong in logic")
# Out:
# something wrong in logic

# %%
# file exception
try:
    with open('sample.txt','r') as f:
        print(f.read())
except Exception as e:
    print('file note exists',e)
# Out:
# file note exists [Errno 2] No such file or directory: 'sample.txt'
