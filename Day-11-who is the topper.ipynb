# %% [markdown]
# ## Who is topper?

# %%
print("Who is the topper")
n = int(input("Enter the no.of studentd in the class: "))
names = []
marks = []
total_marks = []
persentage = []

print("Enter all students marks")
for i in range(n):
    print(f"Enter the roll num {i+1} student marks")
    name = input("ENter the student name: ")
    print("Enter Telugu, English, Hindi, Maths, Science, Social marks, as per the order")
    Telugu, English, Hindi, Maths, Science, Social = map(int, input().split()[:6])
    total_marks = Telugu + English + Hindi + Maths + Science + Social
    std_percentage = (total_marks/600)*100
    # Store all values in list
    names.append(name)
    marks.append([Telugu, English, Hindi, Maths, Science, Social])
    class_marks.append(tatal_marks)
    percentage.append(std_percentage)
# Print the topper details
print("Topper in the class is")
top_marks = max(class_marks)
topper_pos = []
for i in range(n):
    if class_marks[i] == top_marks:
        topers_pos.append(i)
#print the topper details
print("All student marks in the class")
for i in range(len(toppers_pos)):
    print("Name of the student is:", names[i])
    print("Marks of the student is:",marks[i])
    print("Total Marks:", class_marks[i])
# each student marks
for i in range(n):
    print("Name of the student is:",names[i] and "Marks is:",marks[i],' and total marks:',class_marks[i])
# Out:
# Who is the topper
